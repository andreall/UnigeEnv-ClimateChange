# %% [markdown]
# # Google Cloud CMIP6 Public Data: Basic Python Example
#
# *Adapted from:* https://github.com/pangeo-gallery/cmip6/blob/master/basic_search_and_load.ipynb
#
# This notebooks shows how to query the catalog and load the data using python

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import fsspec

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' 
plt.rcParams['figure.figsize'] = 12, 6

# %% [markdown]
# ## Browse Catalog
#
# The data catatalog is stored as a CSV file. Here we read it with Pandas.

# %%
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon          ps         gn
# 1     Amon        rsds         gn
# 2     Amon        rlus         gn
# 3     Amon        rlds         gn
# 4     Amon         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %% [markdown]
# The columns of the dataframe correspond to the CMI6 controlled vocabulary. A beginners' guide to these terms is available in [this document](https://docs.google.com/document/d/1yUx6jr9EdedCOLd--CPdTfGDwEwzPpCF6p1jRmqx-0Q).
#
# Here we filter the data to find monthly surface air temperature for historical experiments.

# %%
df_ta = df.query("activity_id=='CMIP' & table_id == 'Amon' & variable_id == 'tas' & experiment_id == 'historical' & member_id == 'r1i1p1f1'")
df_ta
# Out:
#        activity_id       institution_id          source_id experiment_id  \
# 8074          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 29231         CMIP                 IPSL       IPSL-CM6A-LR    historical
# 32351         CMIP            NASA-GISS        GISS-E2-1-G    historical
# 43297         CMIP                  BCC        BCC-CSM2-MR    historical
# 44593         CMIP                MIROC             MIROC6    historical
# 44888         CMIP                  BCC           BCC-ESM1    historical
# 55765         CMIP                  MRI         MRI-ESM2-0    historical
# 56326         CMIP                 NCAR        CESM2-WACCM    historical
# 59875         CMIP                 NCAR              CESM2    historical
# 68153         CMIP                  SNU        SAM0-UNICON    historical
# 69515         CMIP            NASA-GISS        GISS-E2-1-H    historical
# 100305        CMIP                CCCma            CanESM5    historical
# 204283        CMIP                  INM          INM-CM4-8    historical
# 206457        CMIP                  INM          INM-CM5-0    historical
# 211166        CMIP    HAMMOZ-Consortium    MPI-ESM-1-2-HAM    historical
# 213977        CMIP                NUIST              NESM3    historical
# 217462        CMIP                 CAMS        CAMS-CSM1-0    historical
# 222133        CMIP                MPI-M      MPI-ESM1-2-LR    historical
# 237230        CMIP                MPI-M      MPI-ESM1-2-HR    historical
# 244695        CMIP            NOAA-GFDL          GFDL-ESM4    historical
# 246211        CMIP                   UA         MCM-UA-1-0    historical
# 253043        CMIP            NASA-GISS     GISS-E2-1-G-CC    historical
# 254492        CMIP                  NCC         NorESM2-LM    historical
# 254866        CMIP                  CAS          FGOALS-g3    historical
# 288368        CMIP         E3SM-Project           E3SM-1-0    historical
# 295971        CMIP                  CAS        FGOALS-f3-L    historical
# 376439        CMIP             NIMS-KMA         KACE-1-0-G    historical
# 378954        CMIP         CSIRO-ARCCSS         ACCESS-CM2    historical
# 380148        CMIP                  NCC         NorESM2-MM    historical
# 382611        CMIP             FIO-QLNM        FIO-ESM-2-0    historical
# 383093        CMIP                CSIRO      ACCESS-ESM1-5    historical
# 385224        CMIP                 NCAR          CESM2-FV2    historical
# 385505        CMIP            NASA-GISS        GISS-E2-2-H    historical
# 386297        CMIP                 NCAR    CESM2-WACCM-FV2    historical
# 395013        CMIP         E3SM-Project           E3SM-1-1    historical
# 399318        CMIP            CCCR-IITM           IITM-ESM    historical
# 416230        CMIP                  AWI     AWI-ESM-1-1-LR    historical
# 417295        CMIP  EC-Earth-Consortium   EC-Earth3-Veg-LR    historical
# 425599        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 437788        CMIP                  THU              CIESM    historical
# 450062        CMIP                 CMCC       CMCC-CM2-SR5    historical
# 453022        CMIP              AS-RCEC            TaiESM1    historical
# 453088        CMIP         E3SM-Project       E3SM-1-1-ECA    historical
# 457429        CMIP  EC-Earth-Consortium  EC-Earth3-AerChem    historical
# 459906        CMIP                  AWI      AWI-CM-1-1-MR    historical
# 461085        CMIP                  NCC            NorCPM1    historical
# 463013        CMIP                 IPSL    IPSL-CM5A2-INCA    historical
# 469510        CMIP                 CMCC       CMCC-CM2-HR4    historical
# 507411        CMIP                  CAS         CAS-ESM2-0    historical
# 511505        CMIP  EC-Earth-Consortium       EC-Earth3-CC    historical
# 512190        CMIP                 CMCC          CMCC-ESM2    historical
# 514701        CMIP                MPI-M        ICON-ESM-LR    historical
# 514846        CMIP                 IPSL  IPSL-CM6A-LR-INCA    historical
# 521076        CMIP                KIOST          KIOST-ESM    historical
# 523769        CMIP  EC-Earth-Consortium      EC-Earth3-Veg    historical
#
#        member_id table_id variable_id grid_label  \
# 8074    r1i1p1f1     Amon         tas        gr1
# 29231   r1i1p1f1     Amon         tas         gr
# 32351   r1i1p1f1     Amon         tas         gn
# 43297   r1i1p1f1     Amon         tas         gn
# 44593   r1i1p1f1     Amon         tas         gn
# 44888   r1i1p1f1     Amon         tas         gn
# 55765   r1i1p1f1     Amon         tas         gn
# 56326   r1i1p1f1     Amon         tas         gn
# 59875   r1i1p1f1     Amon         tas         gn
# 68153   r1i1p1f1     Amon         tas         gn
# 69515   r1i1p1f1     Amon         tas         gn
# 100305  r1i1p1f1     Amon         tas         gn
# 204283  r1i1p1f1     Amon         tas        gr1
# 206457  r1i1p1f1     Amon         tas        gr1
# 211166  r1i1p1f1     Amon         tas         gn
# 213977  r1i1p1f1     Amon         tas         gn
# 217462  r1i1p1f1     Amon         tas         gn
# 222133  r1i1p1f1     Amon         tas         gn
# 237230  r1i1p1f1     Amon         tas         gn
# 244695  r1i1p1f1     Amon         tas        gr1
# 246211  r1i1p1f1     Amon         tas         gn
# 253043  r1i1p1f1     Amon         tas         gn
# 254492  r1i1p1f1     Amon         tas         gn
# 254866  r1i1p1f1     Amon         tas         gn
# 288368  r1i1p1f1     Amon         tas         gr
# 295971  r1i1p1f1     Amon         tas         gr
# 376439  r1i1p1f1     Amon         tas         gr
# 378954  r1i1p1f1     Amon         tas         gn
# 380148  r1i1p1f1     Amon         tas         gn
# 382611  r1i1p1f1     Amon         tas         gn
# 383093  r1i1p1f1     Amon         tas         gn
# 385224  r1i1p1f1     Amon         tas         gn
# 385505  r1i1p1f1     Amon         tas         gn
# 386297  r1i1p1f1     Amon         tas         gn
# 395013  r1i1p1f1     Amon         tas         gr
# 399318  r1i1p1f1     Amon         tas         gn
# 416230  r1i1p1f1     Amon         tas         gn
# 417295  r1i1p1f1     Amon         tas         gr
# 425599  r1i1p1f1     Amon         tas         gr
# 437788  r1i1p1f1     Amon         tas         gr
# 450062  r1i1p1f1     Amon         tas         gn
# 453022  r1i1p1f1     Amon         tas         gn
# 453088  r1i1p1f1     Amon         tas         gr
# 457429  r1i1p1f1     Amon         tas         gr
# 459906  r1i1p1f1     Amon         tas         gn
# 461085  r1i1p1f1     Amon         tas         gn
# 463013  r1i1p1f1     Amon         tas         gr
# 469510  r1i1p1f1     Amon         tas         gn
# 507411  r1i1p1f1     Amon         tas         gn
# 511505  r1i1p1f1     Amon         tas         gr
# 512190  r1i1p1f1     Amon         tas         gn
# 514701  r1i1p1f1     Amon         tas         gn
# 514846  r1i1p1f1     Amon         tas         gr
# 521076  r1i1p1f1     Amon         tas        gr1
# 523769  r1i1p1f1     Amon         tas         gr
#
#                                                    zstore  dcpp_init_year  \
# 8074    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 29231   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 32351   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/hi...             NaN
# 43297   gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 44593   gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...             NaN
# 44888   gs://cmip6/CMIP6/CMIP/BCC/BCC-ESM1/historical/...             NaN
# 55765   gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 56326   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 59875   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 68153   gs://cmip6/CMIP6/CMIP/SNU/SAM0-UNICON/historic...             NaN
# 69515   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/hi...             NaN
# 100305  gs://cmip6/CMIP6/CMIP/CCCma/CanESM5/historical...             NaN
# 204283  gs://cmip6/CMIP6/CMIP/INM/INM-CM4-8/historical...             NaN
# 206457  gs://cmip6/CMIP6/CMIP/INM/INM-CM5-0/historical...             NaN
# 211166  gs://cmip6/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ES...             NaN
# 213977  gs://cmip6/CMIP6/CMIP/NUIST/NESM3/historical/r...             NaN
# 217462  gs://cmip6/CMIP6/CMIP/CAMS/CAMS-CSM1-0/histori...             NaN
# 222133  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/hist...             NaN
# 237230  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/hist...             NaN
# 244695  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 246211  gs://cmip6/CMIP6/CMIP/UA/MCM-UA-1-0/historical...             NaN
# 253043  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G-CC...             NaN
# 254492  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...             NaN
# 254866  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-g3/historical...             NaN
# 288368  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-0/hi...             NaN
# 295971  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-f3-L/historic...             NaN
# 376439  gs://cmip6/CMIP6/CMIP/NIMS-KMA/KACE-1-0-G/hist...             NaN
# 378954  gs://cmip6/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/...             NaN
# 380148  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-MM/historica...             NaN
# 382611  gs://cmip6/CMIP6/CMIP/FIO-QLNM/FIO-ESM-2-0/his...             NaN
# 383093  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...             NaN
# 385224  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 385505  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-2-H/hi...             NaN
# 386297  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 395013  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1/hi...             NaN
# 399318  gs://cmip6/CMIP6/CMIP/CCCR-IITM/IITM-ESM/histo...             NaN
# 416230  gs://cmip6/CMIP6/CMIP/AWI/AWI-ESM-1-1-LR/histo...             NaN
# 417295  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 425599  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 437788  gs://cmip6/CMIP6/CMIP/THU/CIESM/historical/r1i...             NaN
# 450062  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
# 453022  gs://cmip6/CMIP6/CMIP/AS-RCEC/TaiESM1/historic...             NaN
# 453088  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1-EC...             NaN
# 457429  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 459906  gs://cmip6/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/histor...             NaN
# 461085  gs://cmip6/CMIP6/CMIP/NCC/NorCPM1/historical/r...             NaN
# 463013  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM5A2-INCA/his...             NaN
# 469510  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-HR4/histor...             NaN
# 507411  gs://cmip6/CMIP6/CMIP/CAS/CAS-ESM2-0/historica...             NaN
# 511505  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 512190  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 514701  gs://cmip6/CMIP6/CMIP/MPI-M/ICON-ESM-LR/histor...             NaN
# 514846  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR-INCA/h...             NaN
# 521076  gs://cmip6/CMIP6/CMIP/KIOST/KIOST-ESM/historic...             NaN
# 523769  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
#
#          version
# 8074    20180701
# 29231   20180803
# 32351   20180827
# 43297   20181126
# 44593   20181212
# 44888   20181214
# 55765   20190222
# 56326   20190227
# 59875   20190308
# 68153   20190323
# 69515   20190403
# 100305  20190429
# 204283  20190530
# 206457  20190610
# 211166  20190627
# 213977  20190630
# 217462  20190708
# 222133  20190710
# 237230  20190710
# 244695  20190726
# 246211  20190731
# 253043  20190815
# 254492  20190815
# 254866  20190818
# 288368  20190913
# 295971  20190927
# 376439  20191028
# 378954  20191108
# 380148  20191108
# 382611  20191115
# 383093  20191115
# 385224  20191120
# 385505  20191120
# 386297  20191120
# 395013  20191211
# 399318  20191226
# 416230  20200212
# 417295  20200217
# 425599  20200310
# 437788  20200417
# 450062  20200616
# 453022  20200623
# 453088  20200623
# 457429  20200624
# 459906  20200720
# 461085  20200724
# 463013  20200729
# 469510  20200904
# 507411  20201227
# 511505  20210113
# 512190  20210114
# 514701  20210215
# 514846  20210216
# 521076  20210601
# 523769  20211207

# %% [markdown]
# Now we do further filtering to find just the models from NCAR.

# %%
df_ta_ncar = df_ta.query('institution_id == "NCAR"')
df_ta_ncar
# Out:
#        activity_id institution_id        source_id experiment_id member_id  \
# 56326         CMIP           NCAR      CESM2-WACCM    historical  r1i1p1f1
# 59875         CMIP           NCAR            CESM2    historical  r1i1p1f1
# 385224        CMIP           NCAR        CESM2-FV2    historical  r1i1p1f1
# 386297        CMIP           NCAR  CESM2-WACCM-FV2    historical  r1i1p1f1
#
#        table_id variable_id grid_label  \
# 56326      Amon         tas         gn
# 59875      Amon         tas         gn
# 385224     Amon         tas         gn
# 386297     Amon         tas         gn
#
#                                                    zstore  dcpp_init_year  \
# 56326   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 59875   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 385224  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 386297  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
#
#          version
# 56326   20190227
# 59875   20190308
# 385224  20191120
# 386297  20191120

# %% [markdown]
# ## Load Data
#
# Now we will load a single store using fsspec, zarr, and xarray.

# %%
df_ta_ncar.zstore.values[0]
# Out:
# 'gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/historical/r1i1p1f1/Amon/tas/gn/v20190227/'

# %%
# get the path to a specific zarr store (the first one from the dataframe above)
zstore = df_ta_ncar.zstore.values[-1]
print(zstore)

# create a mutable-mapping-style interface to the store
mapper = fsspec.get_mapper(zstore)

# open it using xarray and zarr
ds = xr.open_zarr(mapper, consolidated=True)
ds
# Out:
# gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/historical/r1i1p1f1/Amon/tas/gn/v20191120/
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/plugins.py:71: RuntimeWarning: Engine 'cfgrib' loading failed:
# ecCodes library not found using ['eccodes', 'libeccodes.so', 'libeccodes']
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# <xarray.Dataset>
# Dimensions:    (lat: 96, nbnd: 2, lon: 144, time: 1980)
# Coordinates:
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#     lat_bnds   (lat, nbnd) float64 dask.array<chunksize=(96, 2), meta=np.ndarray>
#   * lon        (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     lon_bnds   (lon, nbnd) float64 dask.array<chunksize=(144, 2), meta=np.ndarray>
#   * time       (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     time_bnds  (time, nbnd) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (time, lat, lon) float32 dask.array<chunksize=(990, 96, 144), meta=np.ndarray>
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   674885.0
#     branch_time_in_parent:  10950.0
#     case_id:                1562
#     ...                     ...
#     tracking_id:            hdl:21.14100/2ebbfd9d-97bf-4858-b893-80d31ffe8cc7...
#     variable_id:            tas
#     variant_info:           CMIP6 CESM2 historical ensemble with WACCM6-FV2 (...
#     variant_label:          r1i1p1f1
#     netcdf_tracking_ids:    hdl:21.14100/2ebbfd9d-97bf-4858-b893-80d31ffe8cc7...
#     version_id:             v20191120

# %% [markdown]
# Plot a map from a specific date.

# %%
ds.tas.sel(time='1950-01').squeeze().plot()

# %% [markdown]
# Create a timeseries of global-average surface air temperature. For this we need the area weighting factor for each gridpoint.

# %%
df_area = df.query("variable_id == 'areacella' & source_id == 'CESM2'")
ds_area = xr.open_zarr(fsspec.get_mapper(df_area.zstore.values[0]), consolidated=True)
ds_area
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#     lat_bnds   (lat, nbnd) float32 dask.array<chunksize=(192, 2), meta=np.ndarray>
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#     lon_bnds   (lon, nbnd) float32 dask.array<chunksize=(288, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     areacella  (lat, lon) float32 dask.array<chunksize=(192, 288), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          no parent
#     branch_time_in_child:   711385.0
#     branch_time_in_parent:  0.0
#     case_id:                38
#     ...                     ...
#     variable_id:            areacella
#     variant_info:           f.e21.FHIST_BGC.f09_f09_mg17.CMIP6-AMIP.001
# \n
# \...
#     variant_label:          r1i1p1f1
#     status:                 2019-11-04;created;by nhn2@columbia.edu
#     netcdf_tracking_ids:    hdl:21.14100/23fa9dc3-4f8f-4943-b99b-58eb804c06f0
#     version_id:             v20190218

# %%
total_area = ds_area.areacella.sum(dim=['lon', 'lat'])
ta_timeseries = (ds.tas * ds_area.areacella).sum(dim=['lon', 'lat']) / total_area
ta_timeseries
# Out:
# <xarray.DataArray (time: 1980)>
# dask.array<truediv, shape=(1980,), dtype=float32, chunksize=(990,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00

# %% [markdown]
# By default the data are loaded lazily, as Dask arrays. Here we trigger computation explicitly.

# %%
# %time ta_timeseries.load()
# Out:
# CPU times: user 1.04 s, sys: 334 ms, total: 1.37 s
# Wall time: 6.12 s
# <xarray.DataArray (time: 1980)>
# array([0.00403767, 0.00396339, 0.003874  , ..., 0.00410077, 0.00414687,
#        0.00415227], dtype=float32)
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00

# %%
# Plot the time series of Global Mean Surface Air Temperature
# Plot the rolling mean

# %%
ta_timeseries.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ta_timeseries.plot()
#
# File /opt/anaconda3/lib/python3.8/site-packages/xarray/plot/accessor.py:46, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      44 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      45 def __call__(self, **kwargs) -> Any:
# ---> 46     return dataarray_plot.plot(self._da, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/xarray/plot/dataarray_plot.py:312, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     308     plotfunc = hist
#     310 kwargs["ax"] = ax
# --> 312 return plotfunc(darray, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/xarray/plot/dataarray_plot.py:517, in line(darray, row, col, figsize, aspect, size, ax, hue, x, y, xincrease, yincrease, xscale, yscale, xticks, yticks, xlim, ylim, add_legend, _labels, *args, **kwargs)
#     513 ylabel = label_from_attrs(yplt, extra=y_suffix)
#     515 _ensure_plottable(xplt_val, yplt_val)
# --> 517 primitive = ax.plot(xplt_val, yplt_val, *args, **kwargs)
#     519 if _labels:
#     520     if xlabel is not None:
#
# File /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File /opt/anaconda3/lib/python3.8/site-packages/matplotlib/lines.py:1029, in Line2D.get_path(self)
#    1027 """Return the `~matplotlib.path.Path` associated with this line."""
#    1028 if self._invalidy or self._invalidx:
# -> 1029     self.recache()
#    1030 return self._path
#
# File /opt/anaconda3/lib/python3.8/site-packages/matplotlib/lines.py:657, in Line2D.recache(self, always)
#     655 if always or self._invalidx:
#     656     xconv = self.convert_xunits(self._xorig)
# --> 657     x = _to_unmasked_float_array(xconv).ravel()
#     658 else:
#     659     x = self._x
#
# File /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1335, in _to_unmasked_float_array(x)
#    1333     return np.ma.asarray(x, float).filled(np.nan)
#    1334 else:
# -> 1335     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a number, not 'cftime._cftime.DatetimeNoLeap'

# %%
import pandas as pd

# %%
pd.to_datetimeindex(ta_timeseries.time.data[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pd.to_datetimeindex(ta_timeseries.time.data[0])
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_datetimeindex'
